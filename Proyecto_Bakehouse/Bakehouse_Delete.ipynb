# %% [markdown]
# ### Borrar y crear widgets

# %%
dbutils.widgets.removeAll()
dbutils.widgets.text("catalog", "bakehouse_dev")

catalogName = dbutils.widgets.get("catalog")

# %% [markdown]
# ### Borrar tablas origenes (raw)

# %%
try:
    if any(catalog.name == catalogName for catalog in spark.catalog.listCatalogs()):
        spark.catalog.setCurrentCatalog(catalogName)
        print(f"Catalgo actual: {spark.catalog.currentCatalog()}")

        schemaNames = ["raw", "bronze", "silver", "gold"]
        for schemaName in schemaNames:            
            print(f"Borrando tablas para el esquema: {schemaName}...")
            if spark.catalog.databaseExists(schemaName):
                for table in spark.catalog.listTables(schemaName):
                    spark.sql(f"DROP TABLE IF EXISTS {catalogName}.{schemaName}.{table.name}")
    else:
        print(f"El catalogo {catalogName} no existe.")
except Exception as e:
    msg = f"Error al borrar tablas en el catalog: {catalogName}. Mensaje: {e}"
    #print(msg)
    raise Exception(msg)
# Out:
# Catalgo actual: bakehouse_dev
# Borrando tablas para el esquema: raw...
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7079438440580456>, line 10
#       9 if spark.catalog.databaseExists(schemaName):
# ---> 10     for table in spark.catalog.listTables(schemaName + "_xx"):
#      11         spark.sql(f"DROP TABLE IF EXISTS {catalogName}.{schemaName}.{table.name}")
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/catalog.py:122, in Catalog.listTables(self, dbName, pattern)
#     119 def listTables(
#     120     self, dbName: Optional[str] = None, pattern: Optional[str] = None
#     121 ) -> List[Table]:
# --> 122     table = self._execute_and_fetch(plan.ListTables(db_name=dbName, pattern=pattern))
#     123     return [
#     124         Table(
#     125             name=table[0][i].as_py(),
#    (...)
# ...
